# %% [markdown]
# Guilherme Alexanre - 0050015038

# %%
import pandas as pd
from sklearn.datasets import load_boston

dataset = load_boston()
data = pd.DataFrame(dataset.data)
data.columns = dataset.feature_names
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...  RAD    TAX  PTRATIO       B  LSTAT
# 0  0.00632  18.0   2.31   0.0  0.538  ...  1.0  296.0     15.3  396.90   4.98
# 1  0.02731   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  396.90   9.14
# 2  0.02729   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  392.83   4.03
# 3  0.03237   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  394.63   2.94
# 4  0.06905   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  396.90   5.33
#
# [5 rows x 13 columns]

# %%
data.shape
# Out:
# (506, 13)

# %%
len(dataset.feature_names)
# Out:
# 13

# %%
data['MEDV'] = dataset.target

# %%
import seaborn as sns

# %matplotlib inline

sns.pairplot(data, x_vars=['','ZN','INDUS','NOX'], y_vars='MEDV', height=7, aspect=0.7, kind='reg')

# %%
X = data[data.columns]
y = data['MEDV']
y = data.MEDV

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %% [markdown]
# 8 - Essa base de dados possuem informações acerca do mercado imobilário de Bosto

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=3)

# %% [markdown]
# 10 - Percentual gerado para criar o conjunto de treino é de 75% e 25% para conjunto de teste

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (379, 14)
# (379,)
# (127, 14)
# (127,)

# %%
from sklearn.linear_model import LinearRegression

linreg = LinearRegression()

linreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(linreg.intercept_)
print(linreg.coef_)
# Out:
# 1.3855583347321954e-13
# [-3.64002082e-17 -3.40005801e-16 -5.59990422e-16  6.50961591e-15
#   8.64153855e-15 -1.56301296e-15 -2.11202583e-16  2.39500260e-16
#  -1.14708590e-16 -7.63278329e-17  1.56938264e-17 -2.02962647e-16
#   7.67615138e-17  1.00000000e+00]

# %%
feature_cols = dataset.feature_names
list(zip(feature_cols, linreg.coef_))
# Out:
# [('CRIM', -3.6400208182579047e-17),
#  ('ZN', -3.400058012914542e-16),
#  ('INDUS', -5.59990422088763e-16),
#  ('CHAS', 6.5096159121728545e-15),
#  ('NOX', 8.64153854810562e-15),
#  ('RM', -1.5630129569094153e-15),
#  ('AGE', -2.1120258320017626e-16),
#  ('DIS', 2.3950025990204793e-16),
#  ('RAD', -1.1470858984896637e-16),
#  ('TAX', -7.632783294297951e-17),
#  ('PTRATIO', 1.5693826446727677e-17),
#  ('B', -2.0296264668928643e-16),
#  ('LSTAT', 7.676151381197371e-17)]

# %%
y_pred = linreg.predict(X_test)
print(y_pred)
# Out:
# [44.8 17.1 17.8 33.1 21.9 21.  18.4 10.4 23.1 20.  15.7 41.3 33.3 30.7
#   8.5  6.3 21.2 16.2 15.6 24.1 23.9 50.  23.2 23.4 12.8 24.6 18.8 16.1
#  18.2 24.3 14.8 37.3 21.4 18.6 18.8 13.9 24.5 31.5 18.2 20.7 19.4  9.7
#  21.5 14.9 21.7 26.5 20.7 19.3 24.5 19.3 26.6 23.  45.4 19.8 22.7 23.1
#  50.  17.8 29.1 19.2 22.7 21.2 37.2 31.6 16.1 22.2 34.9 20.5 28.  29.1
#  24.7 22.  15.6 37.  11.8 21.7 19.4 23.3 16.5 16.7 23.9 15.2 11.9 19.9
#  22.8 11.3 25.2 11.5 22.  21.6 19.9 16.8 19.3 50.  29.4 13.3 50.  11.7
#  21.7 33.4 20.2 19.4 14.9 19.6 35.4 12.  20.4 23.7 21.  50.  27.5 12.7
#  17.4 23.8 22.9 18.5 30.3 31.2 16.  23.3 15.  10.2 12.5 19.6 19.7 19.5
#  15. ]

# %%
true = [100, 50, 30, 20]
pred = [90, 50, 50, 30]

print((10 + 0 + 20 + 10)/4.)

from sklearn import metrics
print(metrics.mean_absolute_error(true, pred))
# Out:
# 10.0
# 10.0

# %%
import numpy as np

feature_cols = ['MEDV']

X = data[feature_cols]

y = data.MEDV

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=5)

linreg.fit(X_train, y_train)

y_pred = linreg.predict(X_test)

print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 6.3794803005868234e-15
